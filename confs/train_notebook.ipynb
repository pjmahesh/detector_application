# %%
from matplotlib import pyplot as plt
import matplotlib.image as img
from scipy import ndimage
from scipy import stats

# %matplotlib inline
fig=plt.figure(figsize=(10,10))
plt.rcParams['figure.dpi'] = 250
plt.subplots_adjust(left=1, bottom=1, right=2, top=4)

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# curr=ndimage.rotate(rgb2gray(np.array(Image.open('sample.jpg'))), 270)
curr=ndimage.rotate(np.array(Image.open('Camera02.jpg')), 270)
# curr=np.array(Image.open('sample.jpg'))
plt.imshow(curr)

curr_cutoff=curr[1000:1100,:750,:]

r_mean=np.average(curr_cutoff[:,:,0])
g_mean=np.average(curr_cutoff[:,:,1])
b_mean=np.average(curr_cutoff[:,:,2])

r_dev=np.std(curr_cutoff[:,:,0])
g_dev=np.std(curr_cutoff[:,:,1])
b_dev=np.std(curr_cutoff[:,:,2])
